# %% [markdown]
# ___
# # Exercício: Duas variáveis quantitativas com Discriminação Salarial
# ___
#
# ## Aula 03
#
# <div id="indice"></div>
#
# ## Índice
#
# - [Discriminação Salarial](#discriminacao-salarial)
#     - [Exercício 1](#ex1)
#     - [Exercício 2](#ex2)
#     - [Exercício 3](#ex3)
#     - [Exercício 4](#ex4)
#     - [Exercício 5](#ex5)
#     - [Exercício 6](#ex6)
#     - [Exercício 7](#ex7)
#     - [Exercício 8](#ex8)
#     - [Exercício 9 [EXTRA]](#ex9)
#     - [Exercício 10 [EXTRA]](#ex10)
#     - [Exercício 11 [EXTRA]](#ex11)

# %% [markdown]
# <div id="discriminacao-salarial"></div>
#
# ## <font color='blue'>Discriminação Salarial</font>
#
# Uma empresa está sendo **acusada de pagar um salário maior para os homens do que para as mulheres**.
# Para justificar a acusação, apresentou-se uma lista de salários de uma amostra de funcionários.
# **Essa empresa tem motivos para se preocupar?**
#
# A base de dados `Discriminação.xlsx` apresenta, para cada funcionário, as variáveis:
#
# 1. Sexo (`'fem'` ou `'masc'`);
# 2. Anos (anos no emprego); e
# 3. Salario (salário mensal, em milhares de reais).
# ___

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\matfs\Desktop\Ciência dos Dados\My_CD20-1\CD20-1\aula03

# %%
dados = pd.read_excel('Discriminacao.xlsx')

# %%
dados.head()
# Out:
#   Sexo  Anos  Salario
# 0  fem     9       39
# 1  fem     6       36
# 2  fem    10       40
# 3  fem     0       24
# 4  fem     9       36

# %% [markdown]
# ___
#
# <div id="ex1"></div>
#
# ### EXERCÍCIO 1:
#
# Vamos começar com uma análise descritiva utilizando as ferramentas estatísticas e computacionais que vimos até o momento. Faça essa análise com olhar na preocupação da empresa. Imprima as medidas resumo de posição (média, quartis, máximo, mínimo) e de dispersão (desvio padrão) para o `Salario` dos seguintes grupos:
#
# 1. Conjunto de dados inteiro
# 2. Somente mulheres
# 3. Somente homens
#
# **Preencha os valores das 3 médias na questão 1 da APS 2, no Blackboard**.

# %%
# Escreva seu código aqui
#1. Conjunto inteiro
salarioConj = dados['Salario']
salarioConj.describe()
# Out:
# count    67.000000
# mean     38.343284
# std      10.221119
# min      22.000000
# 25%      31.000000
# 50%      37.000000
# 75%      42.000000
# max      69.000000
# Name: Salario, dtype: float64

# %%
salarioFem = dados.loc[dados.Sexo == 'fem', ['Salario']]
salarioFem.describe()
# Out:
#          Salario
# count  32.000000
# mean   35.468750
# std     7.422652
# min    22.000000
# 25%    29.750000
# 50%    35.000000
# 75%    40.000000
# max    52.000000

# %%
salarioMasc = dados.loc[dados.Sexo == 'masc', ['Salario']]
salarioMasc.describe()
# Out:
#          Salario
# count  35.000000
# mean   40.971429
# std    11.733526
# min    24.000000
# 25%    33.000000
# 50%    39.000000
# 75%    47.000000
# max    69.000000

# %% [markdown]
# <div id="ex2"></div>
#
# ### EXERCÍCIO 2:
#
# Baseando-se nos resultados acima, que hipóteses você pode formular quanto a suspeita de que a empresa está pagando salários mais baixos às mulheres?

# %% [markdown]
# ESCREVA AQUI SUA RESPOSTA

# %% [markdown]
# <div id="ex3"></div>
#
# ### EXERCÍCIO 3:
#
# Calcule os coeficientes de covariância entre as variáveis `Anos` e `Salario` para as mulheres e para os homens, separadamente. **Preencha os dois valores na questão 2 da APS 2, no Blackboard**.

# %%
# Escreva seu código aqui
dados.Anos.cov(salarioFem.Salario)
# Out:
# 28.933467741935484

# %%
dados.Anos.cov(salarioMasc.Salario)
# Out:
# 61.4781512605042

# %% [markdown]
# <div id="ex4"></div>
#
# ### EXERCÍCIO 4:
#
# Baseando-se nos **coeficientes de covariância** acima, você pode concluir que (indique todas as opções corretas):
#
# <ol style="list-style-type: upper-alpha;">
#     <li>Existe uma associação linear <b>negativa</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> das mulheres</li>
#     <li>Existe uma associação linear <b>negativa</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> dos homens</li>
#     <li>Existe uma associação linear <b>positiva</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> das mulheres</li>
#     <li>Existe uma associação linear <b>positiva</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> dos homens</li>
#     <li>Existe uma associação linear <b>fraca</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> das mulheres</li>
#     <li>Existe uma associação linear <b>fraca</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> dos homens</li>
#     <li>Existe uma associação linear <b>forte</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> das mulheres</li>
#     <li>Existe uma associação linear <b>forte</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> dos homens</li>
# </ol>
#
# **Indique sua resposta na questão 3 da APS 2, no Blackboard.**

# %% [markdown]
# ESCREVA SUA RESPOSTA AQUI

# %% [markdown]
# <div id="ex5"></div>
#
# ### EXERCÍCIO 5:
#
# Calcule os coeficientes de correlação linear entre as variáveis `Anos` e `Salario` para as mulheres e para os homens, separadamente. **Preencha os dois valores na questão 4 da APS 2, no Blackboard**.

# %%
# Escreva seu código aqui
dados.Anos.corr(salarioFem.Salario)
# Out:
# 0.8022389898226462

# %%
dados.Anos.corr(salarioMasc.Salario)
# Out:
# 0.6739986401774646

# %% [markdown]
# <div id="ex6"></div>
#
# ### EXERCÍCIO 6:
#
# Baseando-se nos **coeficientes de correlação linear** acima, você pode concluir que (indique todas as opções corretas):
#
# <ol style="list-style-type: upper-alpha;">
#     <li>Existe uma associação linear <b>negativa</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> das mulheres</li>
#     <li>Existe uma associação linear <b>negativa</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> dos homens</li>
#     <li>Existe uma associação linear <b>positiva</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> das mulheres</li>
#     <li>Existe uma associação linear <b>positiva</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> dos homens</li>
#     <li>Existe uma associação linear <b>fraca</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> das mulheres</li>
#     <li>Existe uma associação linear <b>fraca</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> dos homens</li>
#     <li>Existe uma associação linear <b>forte</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> das mulheres</li>
#     <li>Existe uma associação linear <b>forte</b> entre os <code>Anos</code> na empresa e o <code>Salario</code> dos homens</li>
# </ol>
#
# **Indique sua resposta na questão 5 da APS 2, no Blackboard.**

# %% [markdown]
# ESCREVA SUA RESPOSTA AQUI

# %% [markdown]
# <div id="ex7"></div>
#
# ### EXERCÍCIO 7:
#
# Gere os gráficos de dispersão de anos na empresa versus salário mensal para as mulheres e para os homens. Utilize cores diferentes para cada grupo e gere o gráfico em uma figura única.

# %%
# Escreva seu código aqui
fig = plt.figure(figsize=(15, 15))

plt.subplot(2,1,1)
plt.scatter(dados.loc[dados.Sexo == 'fem', ['Anos']], salarioFem.Salario, color='red', alpha=0.4)
plt.title('Anos na empresa x Salário Mensal (Mulheres)')
plt.xlabel('Anos na empresa')
plt.ylabel('Salário Mensal')

plt.subplot(2,1,2)
plt.scatter(dados.loc[dados.Sexo == 'masc', ['Anos']], salarioMasc.Salario, color='blue', alpha=0.4)
plt.title('Anos na empresa x Salário Mensal (Homens)')
plt.xlabel('Anos na empresa')
plt.ylabel('Salário Mensal')
plt.show()

# %% [markdown]
# <div id="ex8"></div>
#
# ### EXERCÍCIO 8:
#
# Como as informações do gráfico acima se relacionam às suas hipóteses no [exercício 2](#ex2)? Você mudaria a sua opinião quanto à suspeita de discriminação salarial? Explique.

# %% [markdown]
# ESCREVA AQUI SUA RESPOSTA

# %% [markdown]
# <div id="ex9"></div>
#
# ### EXERCÍCIO 9 [EXTRA]:
#
# Vamos analisar os dados divididos por faixas de anos na empresa. Crie uma nova coluna `'Faixa'` em `dados` contendo as faixas de anos na empresa. Divida a variável `Anos` em 9 grupos iguais (assim cada faixa conterá um intervalo de 3 anos). Dica: use a função `pd.cut`.

# %%
# Escreva seu código aqui
intervalo = pd.cut(dados.Anos, 3, labels = ["Pouco Tempo", "Tempo Médio", "Muito Tempo"])
dados['Faixa'] = intervalo
dados
# Out:
#     Sexo  Anos  Salario        Faixa
# 0    fem     9       39  Pouco Tempo
# 1    fem     6       36  Pouco Tempo
# 2    fem    10       40  Tempo Médio
# 3    fem     0       24  Pouco Tempo
# 4    fem     9       36  Pouco Tempo
# 5    fem     1       26  Pouco Tempo
# 6    fem     7       31  Pouco Tempo
# 7    fem     6       34  Pouco Tempo
# 8    fem     8       35  Pouco Tempo
# 9    fem     5       27  Pouco Tempo
# 10   fem     3       32  Pouco Tempo
# 11   fem     0       29  Pouco Tempo
# 12   fem     2       30  Pouco Tempo
# 13   fem     5       35  Pouco Tempo
# 14   fem    10       46  Tempo Médio
# 15   fem     6       37  Pouco Tempo
# 16   fem    15       52  Tempo Médio
# 17   fem     3       27  Pouco Tempo
# 18   fem    13       51  Tempo Médio
# 19   fem     1       22  Pouco Tempo
# 20   fem    15       40  Tempo Médio
# 21   fem    12       42  Tempo Médio
# 22   fem     8       29  Pouco Tempo
# 23   fem    14       45  Tempo Médio
# 24   fem    17       42  Tempo Médio
# 25   fem    11       37  Tempo Médio
# 26   fem     7       35  Pouco Tempo
# 27   fem     0       33  Pouco Tempo
# 28   fem     4       37  Pouco Tempo
# 29   fem     0       27  Pouco Tempo
# ..   ...   ...      ...          ...
# 37  masc    18       39  Tempo Médio
# 38  masc    22       69  Muito Tempo
# 39  masc    18       52  Tempo Médio
# 40  masc    19       38  Muito Tempo
# 41  masc     6       25  Pouco Tempo
# 42  masc     9       41  Pouco Tempo
# 43  masc     6       49  Pouco Tempo
# 44  masc     6       36  Pouco Tempo
# 45  masc     5       30  Pouco Tempo
# 46  masc    14       46  Tempo Médio
# 47  masc    22       42  Muito Tempo
# 48  masc    12       55  Tempo Médio
# 49  masc    21       39  Muito Tempo
# 50  masc     6       37  Pouco Tempo
# 51  masc    25       68  Muito Tempo
# 52  masc    27       64  Muito Tempo
# 53  masc     9       35  Pouco Tempo
# 54  masc    15       48  Tempo Médio
# 55  masc     0       42  Pouco Tempo
# 56  masc     3       31  Pouco Tempo
# 57  masc     0       38  Pouco Tempo
# 58  masc     4       26  Pouco Tempo
# 59  masc     0       35  Pouco Tempo
# 60  masc    12       33  Tempo Médio
# 61  masc    13       40  Tempo Médio
# 62  masc    10       29  Tempo Médio
# 63  masc     0       27  Pouco Tempo
# 64  masc    11       31  Tempo Médio
# 65  masc     2       24  Pouco Tempo
# 66  masc    15       33  Tempo Médio
#
# [67 rows x 4 columns]

# %% [markdown]
# <div id="ex10"></div>
#
# ### EXERCÍCIO 10 &#x2605;&#x2605;&#x2605; [EXTRA]:
#
# Imprima as mesmas estatísticas do [exercício 1](#ex1) (salários de todas as pessoas da base de dados, salários das mulheres e salários dos homens), mas agora agrupando por `Faixa`. Dica: use a função `.groupby` de um `DataFrame`.

# %%
# Escreva seu código aqui
salarioConj.groupby(dados.Faixa).describe()
# Out:
#              count       mean        std   min    25%   50%    75%   max
# Faixa
# Pouco Tempo   39.0  33.102564   6.034091  22.0  28.00  35.0  36.50  49.0
# Tempo Médio   20.0  42.850000   7.968854  29.0  38.50  42.0  48.75  56.0
# Muito Tempo    8.0  52.625000  13.070550  38.0  41.25  50.5  65.00  69.0

# %% [markdown]
# <div id="ex11"></div>
#
# ### EXERCÍCIO 11 [EXTRA]:
#
# O resultado acima dá indícios para confirmar ou rejeitar a sua hipótese do [exercício 8](#ex8)?

# %% [markdown]
# ESCREVA AQUI SUA RESPOSTA
